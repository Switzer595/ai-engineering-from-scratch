# %% [markdown]
# # Qwen API in Jupyter Notebook
#
# 这个 Notebook 演示了如何在 Jupyter Notebook 中读取 `.env` 文件里的 DASHSCOPE_API_KEY，并通过 OpenAI 兼容接口调用千问模型。

# %%
question = "请用两句话解释 API 和 SDK 的区别。"

response = client.chat.completions.create(
    model="qwen-plus",
    messages=[
        {"role": "user", "content": question}
    ]
)

print(response.choices[0].message.content)
# Out:
# API（应用程序编程接口）是一组定义软件组件之间如何通信的协议和规则，它规定了请求格式、响应结构及可用功能，但本身不包含实现代码。
# SDK（软件开发工具包）则是一个包含API、库文件、文档、示例代码和开发工具的完整工具集合，旨在帮助开发者更便捷地集成和使用某项服务或平台。

# %%
# %%time

total = 0
for i in range(1000000):
    total += i

print(total)
# Out:
# 499999500000
# CPU times: total: 109 ms
# Wall time: 106 ms
